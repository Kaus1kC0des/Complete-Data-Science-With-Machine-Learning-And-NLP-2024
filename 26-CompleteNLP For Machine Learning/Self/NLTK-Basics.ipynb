# %% [markdown]
# # Tokenization

# %%
import nltk
from nltk import sent_tokenize, word_tokenize
from wandb import sklearn

# %%
corpus = """This is a testing paragraph. I'm feeling very excited about the mistake of joining St. Joseph's College in Chennai.\nLet's see how this mistake impacts my life"""

# %%
documents = sent_tokenize(corpus)

# %%
documents
# Out:
# ['This is a testing paragraph.',
#  "I'm feeling very excited about the mistake of joining St. Joseph's College in Chennai.",
#  "Let's see how this mistake impacts my life"]

# %%
for doc in  documents:
    print(word_tokenize(doc))
# Out:
# ['This', 'is', 'a', 'testing', 'paragraph', '.']
# ['I', "'m", 'feeling', 'very', 'excited', 'about', 'the', 'mistake', 'of', 'joining', 'St.', 'Joseph', "'s", 'College', 'in', 'Chennai', '.']
# ['Let', "'s", 'see', 'how', 'this', 'mistake', 'impacts', 'my', 'life']

# %%
from nltk.tokenize import wordpunct_tokenize


for doc in documents:
    print(wordpunct_tokenize(doc))
# Out:
# ['This', 'is', 'a', 'testing', 'paragraph', '.']
# ['I', "'", 'm', 'feeling', 'very', 'excited', 'about', 'the', 'mistake', 'of', 'joining', 'St', '.', 'Joseph', "'", 's', 'College', 'in', 'Chennai', '.']
# ['Let', "'", 's', 'see', 'how', 'this', 'mistake', 'impacts', 'my', 'life']

# %%
treebankTokenizer = nltk.tokenize.TreebankWordTokenizer()
treebankDeTokenizer = nltk.tokenize.treebank.TreebankWordDetokenizer()
for doc in documents:
    tokens = treebankTokenizer.tokenize(doc)
    print(tokens)
    print(treebankDeTokenizer.detokenize(tokens))
    print()
    print()
# Out:
# ['This', 'is', 'a', 'testing', 'paragraph', '.']
# This is a testing paragraph.
#
#
# ['I', "'m", 'feeling', 'very', 'excited', 'about', 'the', 'mistake', 'of', 'joining', 'St.', 'Joseph', "'s", 'College', 'in', 'Chennai', '.']
# I'm feeling very excited about the mistake of joining St. Joseph's College in Chennai.
#
#
# ['Let', "'s", 'see', 'how', 'this', 'mistake', 'impacts', 'my', 'life']
# Let's see how this mistake impacts my life

# %% [markdown]
# # Stemming

# %%
words = ["fairly", "amazingly", "wonderfully", "successfully", "awesome", "gluey", "history", "wordly", "graffiti", "happily", "flying", "denied", "agreed", "owned"]

# %%
from nltk.stem import *

# %%
stemmers = {
    "Porter": PorterStemmer(),
    "Lancaster": LancasterStemmer(),
    "Snowball": SnowballStemmer("english"),
    "ISRI": ISRIStemmer(),
    "RSLP": RSLPStemmer(),
    "Regexp": RegexpStemmer("ing$|s$|y$"),
    "ARLStem": ARLSTem(),
    "ARLSTem2": ARLSTem2(),
    "Cistem": Cistem()
}

# %%
for word in words:
    for stemmer in stemmers:
        print(f"Original Word: {word} | Stemmer: {stemmer} | Stemmed Word: {stemmers[stemmer].stem(word)}")
    print()
# Out:
# Original Word: fairly | Stemmer: Porter | Stemmed Word: fairli
# Original Word: fairly | Stemmer: Lancaster | Stemmed Word: fair
# Original Word: fairly | Stemmer: Snowball | Stemmed Word: fair
# Original Word: fairly | Stemmer: ISRI | Stemmed Word: fairly
# Original Word: fairly | Stemmer: RSLP | Stemmed Word: fairly
# Original Word: fairly | Stemmer: Regexp | Stemmed Word: fairl
# Original Word: fairly | Stemmer: ARLStem | Stemmed Word: fairly
# Original Word: fairly | Stemmer: ARLSTem2 | Stemmed Word: fairly
# Original Word: fairly | Stemmer: Cistem | Stemmed Word: fairly
#
# Original Word: amazingly | Stemmer: Porter | Stemmed Word: amazingli
# Original Word: amazingly | Stemmer: Lancaster | Stemmed Word: amaz
# Original Word: amazingly | Stemmer: Snowball | Stemmed Word: amaz
# Original Word: amazingly | Stemmer: ISRI | Stemmed Word: amazingly
# Original Word: amazingly | Stemmer: RSLP | Stemmed Word: amazingly
# Original Word: amazingly | Stemmer: Regexp | Stemmed Word: amazingl
# Original Word: amazingly | Stemmer: ARLStem | Stemmed Word: amazingly
# Original Word: amazingly | Stemmer: ARLSTem2 | Stemmed Word: amazingly
# Original Word: amazingly | Stemmer: Cistem | Stemmed Word: amazingly
#
# Original Word: wonderfully | Stemmer: Porter | Stemmed Word: wonder
# Original Word: wonderfully | Stemmer: Lancaster | Stemmed Word: wond
# Original Word: wonderfully | Stemmer: Snowball | Stemmed Word: wonder
# Original Word: wonderfully | Stemmer: ISRI | Stemmed Word: wonderfully
# Original Word: wonderfully | Stemmer: RSLP | Stemmed Word: wonderfully
# Original Word: wonderfully | Stemmer: Regexp | Stemmed Word: wonderfull
# Original Word: wonderfully | Stemmer: ARLStem | Stemmed Word: wonderfully
# Original Word: wonderfully | Stemmer: ARLSTem2 | Stemmed Word: wonderfully
# Original Word: wonderfully | Stemmer: Cistem | Stemmed Word: wonderfully
#
# Original Word: successfully | Stemmer: Porter | Stemmed Word: success
# Original Word: successfully | Stemmer: Lancaster | Stemmed Word: success
# Original Word: successfully | Stemmer: Snowball | Stemmed Word: success
# Original Word: successfully | Stemmer: ISRI | Stemmed Word: successfully
# Original Word: successfully | Stemmer: RSLP | Stemmed Word: successfully
# Original Word: successfully | Stemmer: Regexp | Stemmed Word: successfull
# Original Word: successfully | Stemmer: ARLStem | Stemmed Word: successfully
# Original Word: successfully | Stemmer: ARLSTem2 | Stemmed Word: successfully
# Original Word: successfully | Stemmer: Cistem | Stemmed Word: successfully
#
# Original Word: awesome | Stemmer: Porter | Stemmed Word: awesom
# Original Word: awesome | Stemmer: Lancaster | Stemmed Word: awesom
# Original Word: awesome | Stemmer: Snowball | Stemmed Word: awesom
# Original Word: awesome | Stemmer: ISRI | Stemmed Word: awesome
# Original Word: awesome | Stemmer: RSLP | Stemmed Word: awesom
# Original Word: awesome | Stemmer: Regexp | Stemmed Word: awesome
# Original Word: awesome | Stemmer: ARLStem | Stemmed Word: awesome
# Original Word: awesome | Stemmer: ARLSTem2 | Stemmed Word: awesome
# Original Word: awesome | Stemmer: Cistem | Stemmed Word: awesom
#
# Original Word: gluey | Stemmer: Porter | Stemmed Word: gluey
# Original Word: gluey | Stemmer: Lancaster | Stemmed Word: gluey
# Original Word: gluey | Stemmer: Snowball | Stemmed Word: gluey
# Original Word: gluey | Stemmer: ISRI | Stemmed Word: gluey
# Original Word: gluey | Stemmer: RSLP | Stemmed Word: gluey
# Original Word: gluey | Stemmer: Regexp | Stemmed Word: glue
# Original Word: gluey | Stemmer: ARLStem | Stemmed Word: gluey
# Original Word: gluey | Stemmer: ARLSTem2 | Stemmed Word: gluey
# Original Word: gluey | Stemmer: Cistem | Stemmed Word: gluey
#
# Original Word: history | Stemmer: Porter | Stemmed Word: histori
# Original Word: history | Stemmer: Lancaster | Stemmed Word: hist
# Original Word: history | Stemmer: Snowball | Stemmed Word: histori
# Original Word: history | Stemmer: ISRI | Stemmed Word: history
# Original Word: history | Stemmer: RSLP | Stemmed Word: history
# Original Word: history | Stemmer: Regexp | Stemmed Word: histor
# Original Word: history | Stemmer: ARLStem | Stemmed Word: history
# Original Word: history | Stemmer: ARLSTem2 | Stemmed Word: history
# Original Word: history | Stemmer: Cistem | Stemmed Word: history
#
# Original Word: wordly | Stemmer: Porter | Stemmed Word: wordli
# Original Word: wordly | Stemmer: Lancaster | Stemmed Word: word
# Original Word: wordly | Stemmer: Snowball | Stemmed Word: word
# Original Word: wordly | Stemmer: ISRI | Stemmed Word: wordly
# Original Word: wordly | Stemmer: RSLP | Stemmed Word: wordly
# Original Word: wordly | Stemmer: Regexp | Stemmed Word: wordl
# Original Word: wordly | Stemmer: ARLStem | Stemmed Word: wordly
# Original Word: wordly | Stemmer: ARLSTem2 | Stemmed Word: wordly
# Original Word: wordly | Stemmer: Cistem | Stemmed Word: wordly
#
# Original Word: graffiti | Stemmer: Porter | Stemmed Word: graffiti
# Original Word: graffiti | Stemmer: Lancaster | Stemmed Word: graffit
# Original Word: graffiti | Stemmer: Snowball | Stemmed Word: graffiti
# Original Word: graffiti | Stemmer: ISRI | Stemmed Word: graffiti
# Original Word: graffiti | Stemmer: RSLP | Stemmed Word: graffit
# Original Word: graffiti | Stemmer: Regexp | Stemmed Word: graffiti
# Original Word: graffiti | Stemmer: ARLStem | Stemmed Word: graffiti
# Original Word: graffiti | Stemmer: ARLSTem2 | Stemmed Word: graffiti
# Original Word: graffiti | Stemmer: Cistem | Stemmed Word: graffiti
#
# Original Word: happily | Stemmer: Porter | Stemmed Word: happili
# Original Word: happily | Stemmer: Lancaster | Stemmed Word: happy
# Original Word: happily | Stemmer: Snowball | Stemmed Word: happili
# Original Word: happily | Stemmer: ISRI | Stemmed Word: happily
# Original Word: happily | Stemmer: RSLP | Stemmed Word: happily
# Original Word: happily | Stemmer: Regexp | Stemmed Word: happil
# Original Word: happily | Stemmer: ARLStem | Stemmed Word: happily
# Original Word: happily | Stemmer: ARLSTem2 | Stemmed Word: happily
# Original Word: happily | Stemmer: Cistem | Stemmed Word: happily
#
# Original Word: flying | Stemmer: Porter | Stemmed Word: fli
# Original Word: flying | Stemmer: Lancaster | Stemmed Word: fly
# Original Word: flying | Stemmer: Snowball | Stemmed Word: fli
# Original Word: flying | Stemmer: ISRI | Stemmed Word: flying
# Original Word: flying | Stemmer: RSLP | Stemmed Word: flying
# Original Word: flying | Stemmer: Regexp | Stemmed Word: fly
# Original Word: flying | Stemmer: ARLStem | Stemmed Word: flying
# Original Word: flying | Stemmer: ARLSTem2 | Stemmed Word: flying
# Original Word: flying | Stemmer: Cistem | Stemmed Word: flying
#
# Original Word: denied | Stemmer: Porter | Stemmed Word: deni
# Original Word: denied | Stemmer: Lancaster | Stemmed Word: deny
# Original Word: denied | Stemmer: Snowball | Stemmed Word: deni
# Original Word: denied | Stemmer: ISRI | Stemmed Word: denied
# Original Word: denied | Stemmer: RSLP | Stemmed Word: denied
# Original Word: denied | Stemmer: Regexp | Stemmed Word: denied
# Original Word: denied | Stemmer: ARLStem | Stemmed Word: denied
# Original Word: denied | Stemmer: ARLSTem2 | Stemmed Word: denied
# Original Word: denied | Stemmer: Cistem | Stemmed Word: denied
#
# Original Word: agreed | Stemmer: Porter | Stemmed Word: agre
# Original Word: agreed | Stemmer: Lancaster | Stemmed Word: agree
# Original Word: agreed | Stemmer: Snowball | Stemmed Word: agre
# Original Word: agreed | Stemmer: ISRI | Stemmed Word: agreed
# Original Word: agreed | Stemmer: RSLP | Stemmed Word: agreed
# Original Word: agreed | Stemmer: Regexp | Stemmed Word: agreed
# Original Word: agreed | Stemmer: ARLStem | Stemmed Word: agreed
# Original Word: agreed | Stemmer: ARLSTem2 | Stemmed Word: agreed
# Original Word: agreed | Stemmer: Cistem | Stemmed Word: agreed
#
# Original Word: owned | Stemmer: Porter | Stemmed Word: own
# Original Word: owned | Stemmer: Lancaster | Stemmed Word: own
# Original Word: owned | Stemmer: Snowball | Stemmed Word: own
# Original Word: owned | Stemmer: ISRI | Stemmed Word: owned
# Original Word: owned | Stemmer: RSLP | Stemmed Word: owned
# Original Word: owned | Stemmer: Regexp | Stemmed Word: owned
# Original Word: owned | Stemmer: ARLStem | Stemmed Word: owned
# Original Word: owned | Stemmer: ARLSTem2 | Stemmed Word: owned
# Original Word: owned | Stemmer: Cistem | Stemmed Word: owned

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet = WordNetLemmatizer()

# %%
for doc in documents:
    print(wordnet.lemmatize(doc)    )
# Out:
# This is a testing paragraph.
# I'm feeling very excited about the mistake of joining St. Joseph's College in Chennai.
# Let's see how this mistake impacts my life

# %% [markdown]
# # Bag Of Words

# %%
import pandas as pd
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
import re

# %%
df = pd.read_csv("SpamClassifier-master/smsspamcollection/SMSSpamCollection", sep='\t', names=["label", "message"])

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
stopwords_list = nltk.corpus.stopwords.words('english')

# %%
def preprocess_text(text):
    text = re.sub('[^a-zA-Z]', ' ', text)
    text = text.lower()
    tokenizer = nltk.tokenize.TreebankWordTokenizer()
    lemmatizer = nltk.stem.WordNetLemmatizer()
    tokens_list = tokenizer.tokenize(text)
    tokens_list = [lemmatizer.lemmatize(token) for token in tokens_list if token not in stopwords_list]
    return ' '.join(tokens_list)

# %%
vectorizer = CountVectorizer(lowercase=True, stop_words='english', binary=True, max_features=2000)

# %%
X = df['message']

# %%
X[0], preprocess_text(X[0])
# Out:
# ('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  'go jurong point crazy available bugis n great world la e buffet cine got amore wat')

# %%
X_bow = vectorizer.fit_transform(X)

# %%
X_bow.shape
# Out:
# (5572, 2000)

# %%
print(X_bow[0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 10 stored elements and shape (1, 2000)>
#   Coords	Values
#   (0, 1332)	1
#   (0, 466)	1
#   (0, 234)	1
#   (0, 325)	1
#   (0, 774)	1
#   (0, 1955)	1
#   (0, 977)	1
#   (0, 398)	1
#   (0, 766)	1
#   (0, 1894)	1

# %%
vectorizer.vocabulary_
# Out:
# {'point': 1332,
#  'crazy': 466,
#  'available': 234,
#  'bugis': 325,
#  'great': 774,
#  'world': 1955,
#  'la': 977,
#  'cine': 398,
#  'got': 766,
#  'wat': 1894,
#  'ok': 1237,
#  'lar': 985,
#  'joking': 945,
#  'wif': 1924,
#  'oni': 1244,
#  'free': 701,
#  'entry': 609,
#  'wkly': 1939,
#  'comp': 426,
#  'win': 1928,
#  'cup': 477,
#  'final': 673,
#  'tkts': 1759,
#  'text': 1720,
#  '87121': 123,
#  'receive': 1412,
#  'question': 1379,
#  'std': 1643,
#  'txt': 1807,
#  'rate': 1394,
#  'apply': 202,
#  'dun': 577,
#  'say': 1493,
#  'early': 581,
#  'nah': 1186,
#  'don': 558,
#  'think': 1735,
#  'goes': 755,
#  'usf': 1843,
#  'lives': 1033,
#  'freemsg': 703,
#  'hey': 828,
#  'darling': 497,
#  'week': 1910,
#  'word': 1949,
#  'like': 1023,
#  'fun': 722,
#  'tb': 1700,
#  'xxx': 1973,
#  'send': 1521,
#  '50': 92,
#  'brother': 317,
#  'speak': 1620,
#  'treat': 1787,
#  'request': 1442,
#  'oru': 1260,
#  'set': 1531,
#  'callertune': 342,
#  'callers': 341,
#  'press': 1355,
#  'copy': 450,
#  'friends': 710,
#  'winner': 1930,
#  'valued': 1850,
#  'network': 1198,
#  'customer': 482,
#  'selected': 1514,
#  '900': 128,
#  'prize': 1360,
#  'reward': 1454,
#  'claim': 401,
#  'code': 410,
#  'valid': 1849,
#  '12': 33,
#  'hours': 861,
#  'mobile': 1145,
#  '11': 30,
#  'months': 1159,
#  'entitled': 608,
#  'update': 1831,
#  'latest': 989,
#  'colour': 417,
#  'mobiles': 1146,
#  'camera': 348,
#  'gonna': 760,
#  'home': 847,
#  'soon': 1607,
#  'want': 1886,
#  'talk': 1694,
#  'stuff': 1659,
#  'anymore': 196,
#  'tonight': 1771,
#  've': 1852,
#  'today': 1764,
#  'cash': 362,
#  '100': 25,
#  '20': 48,
#  '000': 1,
#  'pounds': 1344,
#  '87575': 125,
#  'cost': 453,
#  '150p': 40,
#  'day': 503,
#  '16': 43,
#  'reply': 1438,
#  'hl': 836,
#  'info': 899,
#  'urgent': 1836,
#  'won': 1943,
#  'membership': 1118,
#  'www': 1968,
#  'net': 1196,
#  'pobox': 1327,
#  'searching': 1505,
#  'right': 1456,
#  'words': 1950,
#  'thank': 1726,
#  'promise': 1368,
#  'wont': 1948,
#  'help': 827,
#  'wonderful': 1945,
#  'times': 1754,
#  'date': 500,
#  'sunday': 1673,
#  'use': 1840,
#  'credit': 469,
#  'click': 405,
#  'wap': 1890,
#  'link': 1027,
#  'message': 1122,
#  'http': 867,
#  'com': 418,
#  'oh': 1236,
#  'watching': 1896,
#  'eh': 592,
#  'remember': 1431,
#  'yes': 1986,
#  'did': 528,
#  'naughty': 1190,
#  'make': 1082,
#  'wet': 1920,
#  'fine': 675,
#  'way': 1899,
#  'feel': 660,
#  'england': 602,
#  'dont': 559,
#  'miss': 1135,
#  'team': 1705,
#  'news': 1201,
#  'ur': 1833,
#  'national': 1188,
#  '87077': 122,
#  'try': 1796,
#  'seriously': 1528,
#  'going': 757,
#  'ha': 787,
#  'pay': 1281,
#  'da': 488,
#  'stock': 1644,
#  'comin': 423,
#  'aft': 159,
#  'finish': 677,
#  'lunch': 1073,
#  'str': 1650,
#  'lor': 1054,
#  'ard': 208,
#  'smth': 1593,
#  'alright': 183,
#  'meet': 1113,
#  'sooner': 1608,
#  'just': 952,
#  'eat': 585,
#  'really': 1406,
#  'hungry': 870,
#  'tho': 1741,
#  'sucks': 1667,
#  'mark': 1088,
#  'getting': 743,
#  'worried': 1956,
#  'knows': 973,
#  'sick': 1557,
#  'turn': 1803,
#  'pizza': 1307,
#  'lol': 1044,
#  'catch': 364,
#  'bus': 327,
#  'egg': 590,
#  'tea': 1703,
#  'eating': 587,
#  'mom': 1152,
#  'left': 1004,
#  'dinner': 537,
#  'love': 1062,
#  'amp': 186,
#  'car': 352,
#  'll': 1035,
#  'let': 1012,
#  'know': 972,
#  'room': 1467,
#  'work': 1951,
#  'does': 550,
#  'wait': 1876,
#  'sure': 1681,
#  'doesn': 551,
#  'live': 1032,
#  'yeah': 1981,
#  'child': 390,
#  'till': 1752,
#  'doing': 556,
#  'cheers': 387,
#  'tell': 1711,
#  'quick': 1381,
#  'thanks': 1727,
#  'subscription': 1666,
#  'ringtone': 1458,
#  'uk': 1816,
#  'charged': 379,
#  'month': 1158,
#  'confirm': 436,
#  'replying': 1439,
#  'yup': 1998,
#  'look': 1049,
#  'msg': 1172,
#  'learn': 998,
#  '2nd': 66,
#  'lesson': 1010,
#  'oops': 1246,
#  'roommate': 1468,
#  'letter': 1014,
#  'decide': 509,
#  'hello': 826,
#  'saturday': 1488,
#  'texting': 1722,
#  'decided': 510,
#  'tomo': 1767,
#  'trying': 1797,
#  'invite': 913,
#  'pls': 1322,
#  'ahead': 168,
#  'wanted': 1887,
#  'weekend': 1911,
#  'abiola': 134,
#  'forget': 694,
#  'need': 1193,
#  'crave': 465,
#  'sweet': 1686,
#  'tried': 1789,
#  'sms': 1592,
#  'nokia': 1211,
#  'camcorder': 346,
#  '08000930705': 9,
#  'delivery': 520,
#  'tomorrow': 1768,
#  'seeing': 1512,
#  'hope': 851,
#  'man': 1085,
#  'lt': 1070,
#  'gt': 779,
#  'inches': 893,
#  'calls': 344,
#  'messages': 1123,
#  'missed': 1136,
#  'didn': 529,
#  'nigeria': 1204,
#  'hopefully': 852,
#  'tyler': 1812,
#  'maybe': 1104,
#  'ask': 219,
#  'bit': 283,
#  'hospital': 856,
#  'kept': 959,
#  'telling': 1712,
#  'weak': 1901,
#  'time': 1753,
#  'saw': 1492,
#  'class': 402,
#  'usually': 1846,
#  'half': 794,
#  'gets': 741,
#  'second': 1508,
#  'fyi': 725,
#  'ride': 1455,
#  'morning': 1163,
#  'place': 1308,
#  'wow': 1963,
#  'thought': 1742,
#  'liked': 1024,
#  'best': 274,
#  'happy': 809,
#  'sorry': 1610,
#  'ac': 137,
#  'new': 1200,
#  'red': 1417,
#  'play': 1314,
#  'ice': 879,
#  'correct': 451,
#  'end': 595,
#  'yesterday': 1988,
#  'url': 1838,
#  'congrats': 437,
#  'year': 1982,
#  'special': 1621,
#  'cinema': 399,
#  'pass': 1276,
#  'bx420': 332,
#  'ip4': 918,
#  '5we': 100,
#  '150pm': 41,
#  'later': 988,
#  'meeting': 1115,
#  'reached': 1400,
#  'series': 1527,
#  'pick': 1296,
#  'pain': 1269,
#  'good': 761,
#  'joke': 943,
#  'girls': 747,
#  'situation': 1575,
#  'checking': 386,
#  'iq': 920,
#  'took': 1773,
#  'forever': 693,
#  'come': 420,
#  'double': 561,
#  'check': 384,
#  'hair': 792,
#  'said': 1483,
#  'wun': 1967,
#  'cut': 483,
#  'short': 1547,
#  'nice': 1203,
#  'pleased': 1319,
#  'following': 688,
#  'review': 1453,
#  'mob': 1144,
#  'awarded': 240,
#  'bonus': 294,
#  'song': 1603,
#  'frnds': 714,
#  'rply': 1473,
#  'complimentary': 431,
#  'trip': 1790,
#  '1000': 26,
#  'dis': 542,
#  '18': 44,
#  '10': 24,
#  'hear': 818,
#  'comes': 422,
#  'wah': 1875,
#  'lucky': 1072,
#  'save': 1490,
#  'money': 1157,
#  'hee': 822,
#  'finished': 678,
#  'hi': 830,
#  'babe': 244,
#  'im': 888,
#  'wanna': 1885,
#  'xx': 1972,
#  'waiting': 1878,
#  'machan': 1077,
#  'thats': 1729,
#  'cool': 449,
#  'respect': 1444,
#  'pa': 1265,
#  'looking': 1052,
#  'job': 939,
#  'ta': 1689,
#  'ah': 166,
#  'stop': 1646,
#  'urgnt': 1837,
#  'real': 1405,
#  'yo': 1992,
#  'tickets': 1750,
#  'used': 1841,
#  'started': 1636,
#  'came': 347,
#  'bed': 266,
#  'gotta': 768,
#  'kano': 955,
#  'il': 886,
#  'download': 562,
#  'wen': 1918,
#  'stand': 1633,
#  'close': 406,
#  'night': 1205,
#  'spent': 1625,
#  'late': 987,
#  'afternoon': 160,
#  'means': 1108,
#  'haven': 814,
#  'sheets': 1541,
#  'smile': 1587,
#  'pleasure': 1320,
#  'trouble': 1791,
#  'rain': 1388,
#  'hurts': 874,
#  'becoz': 265,
#  'loves': 1067,
#  'smiling': 1589,
#  'service': 1529,
#  'representative': 1441,
#  '0800': 7,
#  '10am': 28,
#  '9pm': 131,
#  'guaranteed': 780,
#  '5000': 94,
#  'havent': 815,
#  'planning': 1312,
#  'buy': 329,
#  '530': 96,
#  'simply': 1564,
#  'password': 1279,
#  'fml': 687,
#  'po': 1326,
#  'box': 305,
#  'movie': 1166,
#  'abt': 136,
#  'loads': 1037,
#  'wk': 1937,
#  'hols': 846,
#  'run': 1477,
#  'forgot': 695,
#  'appointment': 203,
#  'shower': 1553,
#  'cause': 365,
#  'prob': 1361,
#  'coffee': 411,
#  'okay': 1238,
#  'price': 1357,
#  'long': 1047,
#  'legal': 1005,
#  'ave': 235,
#  'gone': 759,
#  'driving': 570,
#  'test': 1719,
#  'mean': 1106,
#  'guess': 782,
#  'gave': 733,
#  'men': 1119,
#  'changed': 376,
#  'search': 1504,
#  'nyc': 1228,
#  'cuz': 486,
#  'page': 1267,
#  'says': 1495,
#  'umma': 1817,
#  'life': 1019,
#  'lot': 1059,
#  'dear': 507,
#  'wishes': 1933,
#  'birthday': 282,
#  'making': 1084,
#  'truly': 1793,
#  'aight': 170,
#  'hit': 834,
#  'address': 152,
#  'considering': 441,
#  'computer': 432,
#  'isn': 923,
#  'old': 1240,
#  'people': 1284,
#  'better': 276,
#  'jokes': 944,
#  'worry': 1958,
#  'busy': 328,
#  'research': 1443,
#  'cos': 452,
#  'things': 1734,
#  'scared': 1496,
#  'mah': 1079,
#  'contact': 442,
#  'weekends': 1912,
#  'draw': 563,
#  'shows': 1555,
#  '12hrs': 34,
#  '150ppm': 42,
#  'juz': 953,
#  'tt': 1799,
#  'eatin': 586,
#  'weight': 1915,
#  'haha': 789,
#  'happened': 805,
#  'entered': 607,
#  'cabin': 334,
#  'boss': 300,
#  'felt': 663,
#  'askd': 220,
#  'invited': 914,
#  'apartment': 199,
#  'went': 1919,
#  'specially': 1622,
#  'holiday': 844,
#  'flights': 684,
#  'operator': 1248,
#  'min': 1128,
#  'friday': 708,
#  'needed': 1194,
#  'hmm': 837,
#  'uncle': 1819,
#  'informed': 902,
#  'paying': 1282,
#  'school': 1500,
#  'directly': 540,
#  'food': 690,
#  'private': 1359,
#  '2004': 52,
#  'account': 143,
#  'statement': 1639,
#  '786': 106,
#  'unredeemed': 1827,
#  'points': 1333,
#  'identifier': 882,
#  'expires': 637,
#  '2000': 50,
#  'caller': 340,
#  '03': 3,
#  'landline': 983,
#  'todays': 1765,
#  'voda': 1862,
#  'numbers': 1224,
#  'ending': 597,
#  '350': 74,
#  'award': 239,
#  'match': 1094,
#  '08712300220': 16,
#  'quoting': 1386,
#  'standard': 1634,
#  'rates': 1395,
#  'app': 200,
#  'mu': 1178,
#  'buying': 330,
#  'yetunde': 1989,
#  'hasn': 811,
#  'sent': 1525,
#  'bother': 301,
#  'sending': 1523,
#  'shouldn': 1552,
#  'girl': 746,
#  'del': 516,
#  'bak': 249,
#  'answer': 192,
#  'sunshine': 1675,
#  'quiz': 1384,
#  'sony': 1605,
#  'dvd': 579,
#  'player': 1316,
#  'country': 457,
#  'ansr': 191,
#  '82277': 114,
#  'sp': 1618,
#  'tyrone': 1814,
#  'laid': 981,
#  'dogging': 554,
#  'locations': 1040,
#  'direct': 539,
#  'join': 941,
#  'largest': 986,
#  'bt': 320,
#  'txting': 1810,
#  'nt': 1219,
#  'ec2a': 588,
#  'haf': 788,
#  'yijue': 1990,
#  'rooms': 1469,
#  'befor': 269,
#  'activities': 147,
#  'msgs': 1174,
#  'chat': 381,
#  'services': 1530,
#  'age': 162,
#  'yr': 1995,
#  'lazy': 994,
#  'type': 1813,
#  'lect': 1002,
#  'sir': 1569,
#  'mail': 1081,
#  'swt': 1688,
#  'tired': 1756,
#  'little': 1031,
#  'lovable': 1061,
#  'persons': 1289,
#  'coz': 461,
#  'biggest': 279,
#  'gud': 781,
#  'ni8': 1202,
#  'open': 1247,
#  'ya': 1976,
#  'whats': 1921,
#  'taking': 1693,
#  'replied': 1437,
#  'sexy': 1535,
#  'local': 1039,
#  'luv': 1074,
#  'netcollex': 1197,
#  'begin': 270,
#  'qatar': 1376,
#  'pray': 1351,
#  'hard': 810,
#  'deleted': 517,
#  'wine': 1929,
#  'thk': 1739,
#  'shirt': 1542,
#  'dream': 564,
#  'joy': 948,
#  'lots': 1060,
#  'tv': 1805,
#  'leaving': 1001,
#  'house': 862,
#  'interview': 911,
#  'boy': 307,
#  'missing': 1137,
#  'years': 1983,
#  'arrange': 215,
#  'safe': 1482,
#  'parents': 1272,
#  'hand': 797,
#  'spend': 1623,
#  'inviting': 915,
#  'friend': 709,
#  '434': 85,
#  'frnd': 713,
#  '62468': 102,
#  'order': 1256,
#  'content': 444,
#  'goto': 767,
#  'internet': 910,
#  'menu': 1120,
#  'wit': 1935,
#  'escape': 612,
#  'fancy': 646,
#  'needs': 1195,
#  'completely': 430,
#  'waste': 1893,
#  'bank': 251,
#  'hmmm': 838,
#  'hop': 850,
#  'muz': 1184,
#  'discuss': 544,
#  'liao': 1016,
#  'coming': 424,
#  'bloody': 289,
#  'hell': 824,
#  'believe': 271,
#  'mr': 1169,
#  'ill': 887,
#  'bath': 255,
#  'carlos': 358,
#  'turns': 1804,
#  'staying': 1642,
#  'til': 1751,
#  'smoke': 1590,
#  'worth': 1960,
#  'doesnt': 552,
#  'log': 1041,
#  'spoke': 1628,
#  'experience': 636,
#  'offer': 1232,
#  'especially': 614,
#  'studying': 1658,
#  'anyways': 198,
#  'gr8': 770,
#  'trust': 1794,
#  'guys': 785,
#  'bye': 333,
#  'working': 1953,
#  'boytoy': 309,
#  'awesome': 242,
#  'minute': 1131,
#  'freephone': 704,
#  '0808': 12,
#  '145': 37,
#  '4742': 86,
#  '9am': 130,
#  '11pm': 32,
#  'xmas': 1971,
#  'radio': 1387,
#  'jus': 951,
#  'bathe': 256,
#  'sis': 1570,
#  'using': 1844,
#  'unique': 1824,
#  'joined': 942,
#  'touch': 1778,
#  'deal': 506,
#  'personal': 1287,
#  'finally': 674,
#  'course': 459,
#  'able': 135,
#  'settled': 1533,
#  'mrng': 1170,
#  'hav': 813,
#  'story': 1649,
#  'dead': 505,
#  'tmr': 1761,
#  'orchard': 1255,
#  'mrt': 1171,
#  'kate': 956,
#  'evening': 620,
#  'bucks': 322,
#  'darlin': 496,
#  'ive': 927,
#  'college': 416,
#  'decimal': 511,
#  'balance': 250,
#  'rs': 1474,
#  'transaction': 1785,
#  'id': 880,
#  'goodmorning': 762,
#  'sleeping': 1581,
#  'dat': 499,
#  'oso': 1261,
#  'oredi': 1258,
#  'straight': 1651,
#  'connection': 440,
#  'shoot': 1544,
#  'big': 278,
#  'ready': 1404,
#  'break': 311,
#  'semester': 1519,
#  'study': 1657,
#  'noe': 1210,
#  'leh': 1006,
#  'sounds': 1616,
#  'slept': 1582,
#  'past': 1280,
#  'nights': 1206,
#  'easy': 584,
#  'sen': 1520,
#  'exam': 626,
#  'march': 1087,
#  'atm': 230,
#  'called': 339,
#  'important': 892,
#  'files': 670,
#  'shop': 1545,
#  'happen': 803,
#  'romantic': 1465,
#  'nite': 1208,
#  '500': 93,
#  'collect': 414,
#  'tc': 1701,
#  'biz': 285,
#  '2optout': 68,
#  'appreciate': 204,
#  'partner': 1274,
#  'career': 355,
#  'start': 1635,
#  'sign': 1560,
#  'company': 427,
#  'bcoz': 261,
#  'lessons': 1011,
#  'walk': 1881,
#  'cross': 472,
#  'road': 1461,
#  'street': 1652,
#  'battery': 258,
#  'died': 532,
#  'flirt': 685,
#  '10p': 29,
#  'sam': 1486,
#  '25': 57,
#  'recd': 1410,
#  'closer': 408,
#  'wil': 1926,
#  'reach': 1399,
#  'theory': 1732,
#  'argument': 212,
#  'wins': 1931,
#  'person': 1286,
#  'argue': 211,
#  'kick': 963,
#  'secret': 1510,
#  'admirer': 153,
#  'reveal': 1451,
#  'thinks': 1738,
#  'laptop': 984,
#  'case': 361,
#  'tel': 1710,
#  'meant': 1109,
#  'told': 1766,
#  'face': 641,
#  'watch': 1895,
#  'fr': 698,
#  'thanx': 1728,
#  'website': 1905,
#  'asked': 221,
#  'kallis': 954,
#  'didnt': 530,
#  'goodnight': 763,
#  'fix': 679,
#  'wake': 1879,
#  'sleep': 1580,
#  'congratulations': 438,
#  'cd': 368,
#  'vouchers': 1868,
#  'music': 1183,
#  '87066': 121,
#  'tncs': 1762,
#  'ldew': 995,
#  'com1win150ppmx3age16': 419,
#  'cal': 337,
#  'hold': 841,
#  'bcums': 262,
#  'angry': 188,
#  'wid': 1923,
#  'dnt': 547,
#  'childish': 391,
#  'true': 1792,
#  'showing': 1554,
#  'deep': 513,
#  'affection': 157,
#  'care': 354,
#  'kettoda': 961,
#  'manda': 1086,
#  'takes': 1691,
#  'lemme': 1008,
#  'expect': 633,
#  'mmm': 1141,
#  'lover': 1065,
#  'video': 1854,
#  'handset': 801,
#  '750': 105,
#  'anytime': 197,
#  'mins': 1130,
#  'unlimited': 1826,
#  'shopping': 1546,
#  'disturb': 545,
#  'ring': 1457,
#  'horny': 854,
#  'naked': 1187,
#  'hot': 858,
#  'unsubscribe': 1830,
#  'dint': 538,
#  'wana': 1884,
#  'plan': 1310,
#  'credits': 471,
#  'choose': 395,
#  'club': 409,
#  'singles': 1567,
#  'quality': 1377,
#  'charge': 378,
#  'sorting': 1613,
#  'ended': 596,
#  'sunny': 1674,
#  'rays': 1396,
#  'leaves': 1000,
#  'worries': 1957,
#  'blue': 290,
#  'bay': 259,
#  'hmv': 839,
#  'questions': 1380,
#  '86688': 120,
#  'bf': 277,
#  'handed': 798,
#  'swing': 1687,
#  'definitely': 515,
#  'far': 650,
#  'okie': 1239,
#  'usual': 1845,
#  'guy': 784,
#  'passed': 1277,
#  'anybody': 195,
#  'throw': 1744,
#  'lets': 1013,
#  'baby': 246,
#  'hour': 860,
#  'fone': 689,
#  'ge': 736,
#  'shall': 1537,
#  'tonite': 1772,
#  'sense': 1524,
#  'stupid': 1660,
#  'cam': 345,
#  'accidentally': 142,
#  'phone': 1291,
#  'sim': 1562,
#  'card': 353,
#  'loyalty': 1069,
#  'ends': 598,
#  'unless': 1825,
#  'hurt': 873,
#  'die': 531,
#  'plz': 1324,
#  'rose': 1470,
#  'bslvyl': 319,
#  'somebody': 1601,
#  'high': 831,
#  'shit': 1543,
#  'scary': 1497,
#  'imagine': 889,
#  'def': 514,
#  'meal': 1105,
#  '4u': 91,
#  '21': 54,
#  'dates': 501,
#  'book': 296,
#  'friendship': 711,
#  'hanging': 802,
#  'themob': 1731,
#  'selection': 1515,
#  'games': 729,
#  'tones': 1770,
#  'babes': 245,
#  'sport': 1630,
#  'aren': 210,
#  'accept': 139,
#  'sister': 1571,
#  'cutefrnd': 485,
#  'belovd': 273,
#  'enemy': 599,
#  'smart': 1586,
#  '200': 49,
#  'weekly': 1913,
#  'cs': 474,
#  '2day': 62,
#  'normal': 1216,
#  'rest': 1446,
#  'wot': 1961,
#  'lost': 1058,
#  'advance': 155,
#  'pongal': 1338,
#  'kb': 957,
#  'power': 1345,
#  'yoga': 1993,
#  'dunno': 578,
#  'dude': 576,
#  'afraid': 158,
#  'december': 508,
#  '11mths': 31,
#  '08002986906': 11,
#  'cake': 336,
#  'merry': 1121,
#  'christmas': 396,
#  'kisses': 970,
#  'cud': 475,
#  'ppl': 1346,
#  'gona': 758,
#  'waitin': 1877,
#  'pete': 1290,
#  'plans': 1313,
#  'flight': 683,
#  'problem': 1363,
#  'track': 1782,
#  'reading': 1403,
#  'read': 1402,
#  'light': 1021,
#  'return': 1449,
#  'immediately': 891,
#  'fixed': 680,
#  'line': 1025,
#  'access': 140,
#  'number': 1223,
#  'chance': 374,
#  'report': 1440,
#  'valentines': 1848,
#  '83600': 116,
#  'rcvd': 1397,
#  'custcare': 481,
#  '08718720201': 20,
#  'surfing': 1683,
#  'calling': 343,
#  'post': 1341,
#  '1000s': 27,
#  'texts': 1723,
#  'wiv': 1936,
#  'interested': 908,
#  'round': 1471,
#  'practice': 1350,
#  'num': 1222,
#  'small': 1585,
#  'txts': 1811,
#  'urself': 1839,
#  'fault': 655,
#  'basically': 254,
#  'figure': 668,
#  'jay': 933,
#  'weed': 1909,
#  'ish': 922,
#  'minutes': 1132,
#  'ago': 165,
#  'wtf': 1966,
#  'met': 1124,
#  'insurance': 906,
#  'allah': 182,
#  'rakhesh': 1391,
#  'ex': 623,
#  'currently': 479,
#  'maximize': 1102,
#  'cc': 367,
#  'hg': 829,
#  'suite342': 1670,
#  '2lands': 63,
#  'row': 1472,
#  'w1j6hl': 1872,
#  'moment': 1153,
#  'st': 1632,
#  'cold': 412,
#  'posted': 1342,
#  'chikku': 389,
#  ...}

# %% [markdown]
# # N Grams Implementation
#
#
# Let us implement N Grams with the CountVectorizer

# %%
n_gram_vectorizer = CountVectorizer(lowercase=True, stop_words='english', ngram_range=(1,2), binary=True, preprocessor=preprocess_text)

# %%
texts = [
    "This is a beautiful day",
    "I love her very much, but she doesn't love me back",
    "This is all about practice"
]

# %%
text_processed =n_gram_vectorizer.fit_transform(texts)

# %%
print(text_processed[0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 3 stored elements and shape (1, 6)>
#   Coords	Values
#   (0, 0)	1
#   (0, 2)	1
#   (0, 1)	1

# %%
for i in texts:
    print(preprocess_text(i))
# Out:
# beautiful day
# love much love back
# practice

# %%
n_gram_vectorizer.vocabulary_
# Out:
# {'beautiful': 0,
#  'day': 2,
#  'beautiful day': 1,
#  'love': 3,
#  'love love': 4,
#  'practice': 5}

# %%
n_gram_vectorizer = CountVectorizer(lowercase=True, stop_words='english', ngram_range=(1, 3), binary=True,
                                    preprocessor=preprocess_text)
text_processed = n_gram_vectorizer.fit_transform(texts)

# %%
print(text_processed[0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 3 stored elements and shape (1, 6)>
#   Coords	Values
#   (0, 0)	1
#   (0, 2)	1
#   (0, 1)	1

# %%
for i in texts:
    print(preprocess_text(i))
# Out:
# beautiful day
# love much love back
# practice

# %%
n_gram_vectorizer.vocabulary_
# Out:
# {'beautiful': 0,
#  'day': 2,
#  'beautiful day': 1,
#  'love': 3,
#  'love love': 4,
#  'practice': 5}
